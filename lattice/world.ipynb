# %%
import matplotlib.pyplot as plt
import seaborn as sns
from world import World  # pyrefly: ignore[missing-import]
s
world = World(33, 57)
world.fill_reactangle(
    8, 15, 11, 4, 1
)  # Fill a rectangle from (0, 0) to (6, 6) with block type 1


world.fill_reactangle(
    7, 10, 6, 9, 2
)

data = world.grid

sns.heatmap(
    data,
    cmap="binary",
    cbar=False,
    linewidths=2,  # linewidths añade el espacio (rejilla) entre cuadros
    linecolor="black",
    square=True,
    xticklabels=range(1, world.width + 1),  # type: ignore
    yticklabels=range(1, world.height + 1),  # type: ignore
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 import seaborn as sns
#       3 from world import World  # pyrefly: ignore[missing-import]
# ----> 4 s
#       5 world = World(33, 57)
#       6 world.fill_reactangle(
#       7     8, 15, 11, 4, 1
#       8 )  # Fill a rectangle from (0, 0) to (6, 6) with block type 1
#
# NameError: name 's' is not defined

# %%
world = World(10, 10)
world.set_block(2, 3, 1)  # Setting block type 1 at (2, 3)

data = world.grid

sns.heatmap(
    data,
    cmap="binary",
    cbar=False,
    linewidths=2,  # linewidths añade el espacio (rejilla) entre cuadros
    linecolor="black",
    square=True,
    xticklabels=range(1, world.width + 1),  # type: ignore
    yticklabels=range(1, world.height + 1),  # type: ignore
)

plt.show()
